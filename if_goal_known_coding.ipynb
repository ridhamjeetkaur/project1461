# %%
import pandas as pd
import numpy as np
import seaborn as sns

# %%
# %matplotlib inline

# %%
df = pd.read_excel('if_goal_known.xlsx')

# %%
df
# Out:
#                                           Professions  \
# 0                                          Pharmacist
# 1                                        Psychologist
# 2                                        Psychologist
# 3                                     Physiotherapist
# 4                                        Psychiatrist
# 5                                   Allopathic doctor
# 6                                     Dental Surgeon
# 7                                    Ayurvedic doctor
# 8                                          Homeopathy
# 9                             Medical Lab Technicians
# 10                             occupational therapist
# 11                                Sanitary Inspector:
# 12                                        Optometrist
# 13                           B.Sc Agriculture Science
# 14                                       B.Sc Nursing
# 15                                    B.Sc - Forestry
# ...

# %%
from sklearn.model_selection import train_test_split

# %%
X = df[['duration for the course for bachelor degree','medical','non medical','commerce','arts']]
y = df['Professions']

# %%
X_train, X_test, y_train, y_test = train_test_split(X, y, test_size=0.30, random_state=70)

# %%
from sklearn.linear_model import LogisticRegression

# %%
logmodel = LogisticRegression()
logmodel.fit(X_train,y_train)
# Out:
# LogisticRegression()

# %%
prediction = logmodel.predict((np.array([[5,1,0,0,1]])))
print(prediction)
if ['prediction' == df['Professions']]:
# Out:
#   File "<ipython-input-59-bacfc8961000>", line 4
#     print(lambda prediction is True : df['recomendation'])
#                             ^
# SyntaxError: invalid syntax

# %%
# want index of prediction
desc=int(input())

# %%
df.loc[0]['recomendation']
# Out:
# 'Highly Recommend to choose'

# %%
df.loc[0]['stream']
# Out:
# 'Medical'
