# %%
import pandas as pd

# %%
aptitude = pd.read_excel('aptitude_data.xlsx')

# %%
aptitude.head()
# Out:
#    Accounts  Business studies  Economics  Mathematics    English  \
# 0  10.00000          10.00000   40.00000     50.00000  50.000000
# 1  10.01002          10.01002   40.01002     50.02004  50.050100
# 2  10.02004          10.02004   40.02004     50.04008  50.100200
# 3  10.03006          10.03006   40.03006     50.06012  50.150301
# 4  10.04008          10.04008   40.04008     50.08016  50.200401
#
#    Computer science   Physics  Chemistry   Biology   History  ...  \
# 0         50.000000  0.000000   0.000000  0.000000  70.00000  ...
# 1         50.050100  0.001002   0.002004  0.002004  70.03006  ...
# 2         50.100200  0.002004   0.004008  0.004008  70.06012  ...
# 3         50.150301  0.003006   0.006012  0.006012  70.09018  ...
# 4         50.200401  0.004008   0.008016  0.008016  70.12024  ...
#
#    event manager.1  Unnamed: 43  Unnamed: 44  Unnamed: 45  Unnamed: 46  \
# 0              NaN          NaN          NaN          NaN          NaN
# ...

# %%
aptitude[['Accounts','streams']][:501]
# Out:
#      Accounts streams
# 0    10.00000    arts
# 1    10.01002    arts
# 2    10.02004    arts
# 3    10.03006    arts
# 4    10.04008    arts
# ..        ...     ...
# 496  14.96994    arts
# 497  14.97996    arts
# 498  14.98998    arts
# 499  15.00000    arts
# 500  15.01002    arts
#
# [501 rows x 2 columns]

# %%
import numpy as np


# ARTS
acc =np.linspace(10,20,999)
aptitude['Accounts'][:999]=acc
aptitude.head(999)

bus =np.linspace(10,20,999)
aptitude['Business studies'][:999]=bus
aptitude.head(999)

eco =np.linspace(40,50,999)
aptitude['Economics'][:999]=eco
aptitude.head(999)

math =np.linspace(50,70,999)
aptitude['Mathematics'][:999]=math
aptitude.head(999)

eng =np.linspace(50,100,999)
aptitude['English'][:999]=eng
aptitude.head(999)

cs =np.linspace(50,100,999)
aptitude['Computer science'][:999]=cs
aptitude.head(999)

phy =np.linspace(0,1,999)
aptitude['Physics'][:999]=phy
aptitude.head(999)

chem =np.linspace(0,2,999)
aptitude['Chemistry'][:999]=chem
aptitude.head(999)

bio =np.linspace(0,2,999)
aptitude['Biology'][:999]=bio
aptitude.head(999)

his =np.linspace(70,100,999)
aptitude['History'][:999]=his
aptitude.head(999)

geo =np.linspace(70,100,999)
aptitude['Geography'][:999]=geo
aptitude.head(999)

ps =np.linspace(50,100,999)
aptitude['Political science'][:999]=ps
aptitude.head(999)

oe =np.linspace(0,80,999)
aptitude['observation/experiment'][:999]=oe
aptitude.head(999)

spo =np.linspace(0,100,999)
aptitude['sports'][:999]=spo
aptitude.head(999)

sh =np.linspace(1,4,999)
aptitude['study hours'][:999]=sh
aptitude.head(999)
# Out:
# <ipython-input-22-7d3c070f5f72>:6: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   aptitude['Accounts'][:999]=acc
# <ipython-input-22-7d3c070f5f72>:10: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   aptitude['Business studies'][:999]=bus
# <ipython-input-22-7d3c070f5f72>:14: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   aptitude['Economics'][:999]=eco
# <ipython-input-22-7d3c070f5f72>:18: SettingWithCopyWarning:
# ...

# %%
aptitude['streams'][999:1999]
# Out:
# 999     commerce
# 1000    commerce
# 1001    commerce
# 1002    commerce
# 1003    commerce
#           ...
# 1994    commerce
# 1995    commerce
# 1996    commerce
# 1997    commerce
# 1998    commerce
# Name: streams, Length: 1000, dtype: object

# %%
import numpy as np


# commerce
acc =np.linspace(80,100,1000)
aptitude['Accounts'][999:1999]=acc
aptitude[999:1999]

bus =np.linspace(80,100,1000)
aptitude['Business studies'][999:1999]=bus
aptitude[999:1999]

eco =np.linspace(50,100,1000)
aptitude['Economics'][999:1999]=eco
aptitude[999:1999]

math =np.linspace(50,80,1000)
aptitude['Mathematics'][999:1999]=math
aptitude[999:1999]

eng =np.linspace(50,100,1000)
aptitude['English'][999:1999]=eng
aptitude[999:1999]

cs =np.linspace(20,100,1000)
aptitude['Computer science'][999:1999]=cs
aptitude[999:1999]

phy =np.linspace(0,20,1000)
aptitude['Physics'][999:1999]=phy
aptitude[999:1999]

chem =np.linspace(0,20,1000)
aptitude['Chemistry'][999:1999]=chem
aptitude[999:1999]

bio =np.linspace(0,20,1000)
aptitude['Biology'][999:1999]=bio
aptitude[999:1999]

his =np.linspace(0,50,1000)
aptitude['History'][999:1999]=his
aptitude[999:1999]

geo =np.linspace(0,20,1000)
aptitude['Geography'][999:1999]=geo
aptitude[999:1999]

ps =np.linspace(0,40,1000)
aptitude['Political science'][999:1999]=ps
aptitude[999:1999]

oe =np.linspace(0,80,1000)
aptitude['observation/experiment'][999:1999]=oe
aptitude[999:1999]

spo =np.linspace(0,100,1000)
aptitude['sports'][999:1999]=spo
aptitude[999:1999]

sh =np.linspace(3,5,1000)
aptitude['study hours'][999:1999]=sh
aptitude[999:1999]
# Out:
# <ipython-input-23-73831a7dd202>:6: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   aptitude['Accounts'][999:1999]=acc
# <ipython-input-23-73831a7dd202>:10: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   aptitude['Business studies'][999:1999]=bus
# <ipython-input-23-73831a7dd202>:14: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   aptitude['Economics'][999:1999]=eco
# ...

# %%
aptitude['streams'][1999:3000]
# Out:
# 1999        medical
# 2000        medical
# 2001        medical
# 2002        medical
# 2003        medical
#            ...
# 2995        medical
# 2996        medical
# 2997        medical
# 2998        medical
# 2999    non medical
# Name: streams, Length: 1001, dtype: object

# %%
import numpy as np


# medical
acc =np.linspace(0,20,1001)
aptitude['Accounts'][1999:3000]=acc
aptitude[1999:3000]

bus =np.linspace(0,20,1001)
aptitude['Business studies'][1999:3000]=bus
aptitude[1999:3000]

eco =np.linspace(0,10,1001)
aptitude['Economics'][1999:3000]=eco
aptitude[1999:3000]

math =np.linspace(0,30,1001)
aptitude['Mathematics'][1999:3000]=math
aptitude[1999:3000]

eng =np.linspace(0,100,1001)
aptitude['English'][1999:3000]=eng
aptitude[1999:3000]

cs =np.linspace(20,50,1001)
aptitude['Computer science'][1999:3000]=cs
aptitude[1999:3000]

phy =np.linspace(80,100,1001)
aptitude['Physics'][1999:3000]=phy
aptitude[1999:3000]

chem =np.linspace(80,100,1001)
aptitude['Chemistry'][1999:3000]=chem
aptitude[1999:3000]

bio =np.linspace(90,100,1001)
aptitude['Biology'][1999:3000]=bio
aptitude[1999:3000]

his =np.linspace(0,20,1001)
aptitude['History'][1999:3000]=his
aptitude[1999:3000]

geo =np.linspace(0,20,1001)
aptitude['Geography'][1999:3000]=geo
aptitude[1999:3000]

ps =np.linspace(0,30,1001)
aptitude['Political science'][1999:3000]=ps
aptitude[1999:3000]

oe =np.linspace(50,100,1001)
aptitude['observation/experiment'][1999:3000]=oe
aptitude[1999:3000]

spo =np.linspace(0,90,1001)
aptitude['sports'][1999:3000]=spo
aptitude[1999:3000]

sh =np.linspace(6,18,1001)
aptitude['study hours'][1999:3000]=sh
aptitude[1999:3000]
# Out:
# <ipython-input-24-eb3d7583500a>:6: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   aptitude['Accounts'][1999:3000]=acc
# <ipython-input-24-eb3d7583500a>:10: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   aptitude['Business studies'][1999:3000]=bus
# <ipython-input-24-eb3d7583500a>:14: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   aptitude['Economics'][1999:3000]=eco
# ...

# %%
aptitude['streams'][3000:]
# Out:
# 3000    non medical
# 3001    non medical
# 3002    non medical
# 3003    non medical
# 3004    non medical
#            ...
# 3994    non medical
# 3995    non medical
# 3996    non medical
# 3997    non medical
# 3998    non medical
# Name: streams, Length: 999, dtype: object

# %%
import numpy as np


# non medical
acc =np.linspace(0,40,999)
aptitude['Accounts'][3000:]=acc
aptitude[3000:]

bus =np.linspace(0,20,999)
aptitude['Business studies'][3000:]=bus
aptitude[3000:]

eco =np.linspace(80,100,999)
aptitude['Economics'][3000:]=eco
aptitude[3000:]

math =np.linspace(70,100,999)
aptitude['Mathematics'][3000:]=math
aptitude[3000:]

eng =np.linspace(0,100,999)
aptitude['English'][3000:]=eng
aptitude[3000:]

cs =np.linspace(50,100,999)
aptitude['Computer science'][3000:]=cs
aptitude[3000:]

phy =np.linspace(80,100,999)
aptitude['Physics'][3000:]=phy
aptitude[3000:]

chem =np.linspace(80,100,999)
aptitude['Chemistry'][3000:]=chem
aptitude[3000:]

bio =np.linspace(0,30,999)
aptitude['Biology'][3000:]=bio
aptitude[3000:]

his =np.linspace(0,20,999)
aptitude['History'][3000:]=his
aptitude[3000:]

geo =np.linspace(0,20,999)
aptitude['Geography'][3000:]=geo
aptitude[3000:]

ps =np.linspace(0,30,999)
aptitude['Political science'][3000:]=ps
aptitude[3000:]

oe =np.linspace(50,100,999)
aptitude['observation/experiment'][3000:]=oe
aptitude[3000:]

spo =np.linspace(0,100,999)
aptitude['sports'][3000:]=spo
aptitude[3000:]

sh =np.linspace(7,18,999)
aptitude['study hours'][3000:]=sh
aptitude[3000:]
# Out:
# <ipython-input-26-b9247931b304>:6: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   aptitude['Accounts'][3000:]=acc
# <ipython-input-26-b9247931b304>:10: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   aptitude['Business studies'][3000:]=bus
# <ipython-input-26-b9247931b304>:14: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   aptitude['Economics'][3000:]=eco
# <ipython-input-26-b9247931b304>:18: SettingWithCopyWarning:
# ...

# %%
aptitude.to_excel('aptitude_file.xlsx')
